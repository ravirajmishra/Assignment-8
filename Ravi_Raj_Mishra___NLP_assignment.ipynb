# %% [markdown]
# <a href="https://colab.research.google.com/github/ravirajmishra/Assignment-8/blob/main/Ravi_Raj_Mishra___NLP_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MCQ Question Generator using Spacy Library
# This code generates multiple-choice questions (MCQs) based on a given context paragraph using the Spacy library.

# %%
# import Libary
import spacy
import random

# Load English language model
nlp = spacy.load("en_core_web_sm")

def get_mca_questions(context: str, num_questions: int): # Define function
    doc = nlp(context)

    def generate_mcq_with_multiple_correct(question, correct_answers, other_options, num_options=4): # Define MCQ generation function
        options = correct_answers + other_options
        random.shuffle(options)

        mcq = {
            "question": question,
            "options": options,
            "correct_answers": correct_answers
        }

        return mcq

    def generate_variety_question(): # Generate a variety question
        sentence = random.choice(list(doc.sents))
        blank_word = random.choice([token for token in sentence if not token.is_punct])

        question_text = sentence.text.replace(blank_word.text, "______")
        correct_answers = [blank_word.text]

        other_options = [token.text for token in doc if token.is_alpha and token.text != correct_answers[0]]
        num_correct_options = random.randint(1, 2)  # Generate 1 or 2 correct options
        correct_answers.extend(random.sample(other_options, num_correct_options))

        num_other_options = min(4 - num_correct_options, len(other_options))
        other_options = random.sample(other_options, num_other_options)

        mcq = generate_mcq_with_multiple_correct(question_text, correct_answers, other_options)
        return mcq

    questions = [generate_variety_question() for _ in range(num_questions)]

    mca_questions = [] # Generate questions & Process and format questions
    for i, question in enumerate(questions, start=1):
        question_str = f"Q{i}: {question['question']}\n"
        options_str = ""
        for j, option in enumerate(question['options']):
            options_str += f"{j+1}. {option}\n"

        correct_options_formatted = " & ".join([f"({chr(97+question['options'].index(ans))})" for ans in question['correct_answers']])
        correct_options_str = f"Correct Options: {correct_options_formatted}"

        mca_question = f"{question_str}{options_str}{correct_options_str}\n"
        mca_questions.append(mca_question)

    return mca_questions

context = input("Enter the paragraph: ")
num_questions = int(input("Enter the number of questions: "))
mca_questions = get_mca_questions(context, num_questions)
for question in mca_questions:
    print(question)
# Out:
# Enter the paragraph: Photosynthesis is a process used by plants and other organisms to convert light energy into chemical energy that, through cellular respiration, can later be released to fuel the organism's activities. Some of this chemical energy is stored in carbohydrate molecules, such as sugars and starches, which are synthesized from carbon dioxide and water – hence the name photosynthesis, from the Greek phōs, "light", and synthesis , "putting together". Most plants, algae, and cyanobacteria perform photosynthesis; such organisms are called photoautotrophs. Photosynthesis is largely responsible for producing and maintaining the oxygen content of the Earth's atmosphere, and supplies most of the energy necessary for life on Earth. Although photosynthesis is performed differently by different species, the process always begins when energy from light is absorbed by proteins called reaction centers that contain green chlorophyll (and other colored) pigments/chromophores. In plants, these proteins are held inside organelles called chloroplasts, which are most abundant in leaf cells, while in bacteria they are embedded in the plasma membrane. In these light-dependent reactions, some energy is used to strip electrons from suitable substances, such as water, producing oxygen gas. The hydrogen freed by the splitting of water is used in the creation of two further compounds that serve as short-term stores of energy, enabling its transfer to drive other reactions: these compounds are reduced nicotinamide adenine dinucleotide phosphate (NADPH) and adenosine triphosphate (ATP), the "energy currency" of cells. In plants, algae and cyanobacteria, sugars are synthesized by a subsequent sequence of light-independent reactions called the Calvin cycle. In the Calvin cycle, atmospheric carbon dioxide is incorporated into already existing organic carbon compounds, such as ribulose bisphosphate (RuBP).[5] Using the ATP and NADPH produced by the light-dependent reactions, the resulting compounds are then reduced and removed to form further carbohydrates, such as glucose. In other bacteria, different mechanisms such as the reverse Krebs cycle are used to achieve the same end. The first photosynthetic organisms probably evolved early in the evolutionary history of life and most likely used reducing agents such as hydrogen or hydrogen sulfide, rather than water, as sources of electrons. Cyanobacteria appeared later; the excess oxygen they produced contributed directly to the oxygenation of the Earth, which rendered the evolution of complex life possible. Today, the average rate of energy capture by photosynthesis globally is approximately 130 terawatts, which is about eight times the current power consumption of human civilization. Photosynthetic organisms also convert around 100–115 billion tons (91–104 Pg petagrams, or billion metric tons), of carbon into biomass per year. That plants receive some energy from light – in addition to air, soil, and water – was first discovered in 1779 by Jan Ingenhousz.
# Enter the number of questions: 30
# Q1: In these light-dependent reactions, some energy is used to strip electrons from suitable substances, such ______ water, producing oxygen g______.
# 1. called
# 2. nicotinamide
# 3. sequence
# 4. light
# 5. as
# Correct Options: (e) & (c)
#
# Q2: Photosynthetic organisms also convert around 100–115 billion tons (91–104 Pg petagrams, or billion metric tons), of carbon into biomass per ______.
# 1. from
# 2. year
# 3. adenosine
# 4. organic
# 5. of
# Correct Options: (b) & (d) & (c)
#
# Q3: Although photosynthes______ ______ performed differently by different species, the process always begins when energy from light ______ absorbed by proteins called reaction centers that contain green chlorophyll (and other colored) pigments/chromophores.
# 1. organelles
# 2. is
# 3. removed
# 4. strip
# 5. which
# Correct Options: (b) & (d) & (c)
#
# Q4: In the Calvin cycle, atmospheric carbon dioxide is incorporated into already existing organic carbon compounds, such as ribulose bisphosphate (RuBP).[5] Using the ATP and NADPH produced by the light-dependent reactions, the resulting compounds ______ then reduced and removed to form further carbohydrates, such as glucose.
# 1. begins
# 2. reverse
# 3. are
# 4. compounds
# 5. supplies
# Correct Options: (c) & (d) & (a)
#
# Q5: Photosynthesis is largely responsible for producing and maintaining the oxygen content ______ the Earth's atmosphere, and supplies most ______ the energy necessary for life on Earth.
# 1. of
# 2. times
# 3. perform
# 4. oxygenation
# 5. bacteria
# Correct Options: (a) & (e)
#
# Q6: Today, the average ______ of energy capture by photosynthesis globally is approximately 130 terawatts, which is about eight times the current power consumption of human civilization.
# 1. reactions
# 2. rate
# 3. the
# 4. The
# 5. they
# Correct Options: (b) & (a) & (c)
#
# Q7: In these light-dependent reactions, some energy is used to strip electrons ______ suitable substances, such as water, producing oxygen gas.
# 1. from
# 2. into
# 3. contain
# 4. energy
# 5. current
# Correct Options: (a) & (c)
#
# Q8: In plants, algae and cyanobacteria, sugars are synthesized by a subsequent sequence of light-______ reactions called the Calvin cycle.
# 1. independent
# 2. agents
# 3. short
# 4. inside
# 5. reduced
# Correct Options: (a) & (b)
#
# Q9: ______ these light-dependent reactions, some energy is used to strip electrons from suitable substances, such as water, producing oxygen gas.
# 1. necessary
# 2. cellular
# 3. life
# 4. rendered
# 5. In
# Correct Options: (e) & (a)
#
# Q10: Photosynthesis is largely responsible for producing and maintaining the oxygen ______ of the Earth's atmosphere, and supplies most of the energy necessary for life on Earth.
# 1. billion
# 2. plasma
# 3. held
# 4. the
# 5. content
# Correct Options: (e) & (b)
#
# Q11: In the Calvin cycle, atmospheric carbon dioxide is incorporated into already existing organic carbon compounds, such as ribulose bisphosphate (RuBP).[5] Using the ATP and NADPH produced by the light-______ reactions, the resulting compounds are then reduced and removed to form further carbohydrates, such as glucose.
# 1. which
# 2. energy
# 3. of
# 4. dependent
# 5. activities
# Correct Options: (d) & (a) & (e)
#
# Q12: That plants receive some energy from light – in addition to air, soil, and water – ______ first discovered in 1779 by Jan Ingenhousz.
# 1. was
# 2. water
# 3. a
# 4. in
# 5. receive
# Correct Options: (a) & (d)
#
# Q13: Cyanobacteria appeared later; the excess oxygen they produced contributed directly ______ the oxygenation of the Earth, which rendered the evolution of complex life possible.
# 1. carbohydrates
# 2. such
# 3. are
# 4. to
# 5. the
# Correct Options: (d) & (b) & (c)
#
# Q14: That plants receive some energy from light – in addition to air, soil, and water – was ______ discovered in 1779 by Jan Ingenhousz.
# 1. producing
# 2. algae
# 3. life
# 4. first
# 5. in
# Correct Options: (d) & (a) & (b)
#
# Q15: Although photosynthesis is performed differently by different species, the process always begins ______ energy from light is absorbed by proteins called reaction centers that contain green chlorophyll (and other colored) pigments/chromophores.
# 1. In
# 2. in
# 3. probably
# 4. then
# 5. when
# Correct Options: (e) & (d)
#
# Q16: In ______ light-dependent reactions, some energy is used to strip electrons from suitable substances, such as water, producing oxygen gas.
# 1. these
# 2. cellular
# 3. are
# 4. energy
# 5. in
# Correct Options: (a) & (b)
#
# Q17: In o______r bacteria, different mechanisms such as ______ reverse Krebs cycle are used to achieve ______ same end.
# 1. cellular
# 2. already
# 3. resulting
# 4. the
# 5. necessary
# Correct Options: (d) & (c) & (b)
#
# Q18: Although photosynthesis is performed differently by different species, the process always begins when energy from light is absorbed by proteins called reaction centers that contain green chlorophyll (and other ______) pigments/chromophores.
# 1. of
# 2. colored
# 3. terawatts
# 4. In
# 5. by
# Correct Options: (b) & (a)
#
# Q19: Some of this chemical energy is stored in carbohydrate molecules, such as sugars and starches, which are synthesized from carbon dioxide and water – hence the name photosynthesis, from the Greek ______, "light", and synthesis , "putting together".
# 1. phōs
# 2. as
# 3. Cyanobacteria
# 4. atmosphere
# 5. the
# Correct Options: (a) & (b)
#
# Q20: In the Calvin cycle, atmospheric carbon dioxide is incorporated into already existing organic carbon compounds, such ______ ribulose bisphosphate (RuBP).[5] Using the ATP and NADPH produced by the light-dependent reactions, the resulting compounds are then reduced and removed to form further carbohydrates, such ______ glucose.
# 1. as
# 2. and
# 3. possible
# 4. oxygen
# 5. hence
# Correct Options: (a) & (d)
#
# Q21: In other bacteria, different mechanisms such as the reverse Krebs cycle ______ used to achieve the same end.
# 1. carbohydrate
# 2. energy
# 3. cycle
# 4. the
# 5. are
# Correct Options: (e) & (d)
#
# Q22: The hydrogen freed by the splitting of water is used in the creation of two further compounds that serve as short-term stores of ______, enabling its transfer to drive other reactions: these compounds are reduced nicotinamide adenine dinucleotide phosphate (NADPH) and adenosine triphosphate (ATP), the "______ currency" of cells.
# 1. cycle
# 2. light
# 3. content
# 4. energy
# 5. in
# Correct Options: (d) & (c)
#
# Q23: In the Calvin cycle, atmospheric carbon dioxide is incorporated into already existing organic carbon compounds, such as ribulose bisphosphate (RuBP).[5] Using the ATP and NADPH produced by the light-dependent reactions, the resulting compounds are ______ reduced and removed to form further carbohydrates, such as glucose.
# 1. and
# 2. and
# 3. phōs
# 4. then
# 5. in
# Correct Options: (d) & (a) & (e)
#
# Q24: Some of this chemical energy is stored in carbohydrate molecules, such as sugars and starches, which are synthesized from carbon dioxide and water – hence the name photosynthesis, from the Greek ______, "light", and synthesis , "putting together".
# 1. resulting
# 2. phōs
# 3. from
# 4. this
# 5. for
# Correct Options: (b) & (a)
#
# Q25: Photosynthesis is a process used by plants and other organisms to convert light energy into chemical energy that, through cellular respiration, can later ______ released to fuel the organism's activities.
# 1. sulfide
# 2. Photosynthesis
# 3. be
# 4. drive
# 5. called
# Correct Options: (c) & (e) & (d)
#
# Q26: In these light-dependent reactions, some energy is used to strip electrons from suitable substances, such as water, producing ______ gas.
# 1. energy
# 2. contributed
# 3. the
# 4. centers
# 5. oxygen
# Correct Options: (e) & (c)
#
# Q27: In plants, ______ proteins are held inside organelles called chloroplasts, which are most abundant in leaf cells, while in bacteria they are embedded in the plasma membrane.
# 1. proteins
# 2. agents
# 3. these
# 4. the
# 5. by
# Correct Options: (c) & (b) & (e)
#
# Q28: In plants, algae ______ cyanobacteria, sugars are synthesized by a subsequent sequence of light-independent reactions called the Calvin cycle.
# 1. organic
# 2. reverse
# 3. and
# 4. are
# 5. content
# Correct Options: (c) & (b) & (e)
#
# Q29: Photosynthesis is a ______ used by plants and other organisms to convert light energy into chemical energy that, through cellular respiration, can later be released to fuel the organism's activities.
# 1. independent
# 2. is
# 3. transfer
# 4. petagrams
# 5. process
# Correct Options: (e) & (d)
#
# Q30: Most plants, algae, and ______ perform photosynthesis; such organisms are called photoautotrophs.
# 1. convert
# 2. cyanobacteria
# 3. and
# 4. convert
# 5. is
# Correct Options: (b) & (a) & (e)
